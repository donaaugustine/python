# %%
#1 Print your address
name = input("Enter name : ")
age=int(input("Enter age : "))
address=input("Enter address : ")
print("...Personal Details...")
print("Name : " , name , "\nAge : " , age , "\naddress : " , address )
# Out:
# Enter name : Dona
# Enter age : 20
# Enter address : Green villa,Green valley,Kottayam
# ...Personal Details...
# Name :  Dona
# Age :  20
# address :  Green villa,Green valley,Kottayam

# %%
#2 Display future leap years from current year to a final year entered by user
y = int(input("Enter the final year : "))
print("Future leap years from 2021 : ")
for x in range (2021 , y+1):
 if((x%4==0) and (x%100!=0)) or (x%400==0):
   print(x)
# Out:
# Enter the final year : 2030
# Future leap years from 2021 :
# 2024
# 2028

# %%
#3a Generate positive list of numbers from a given list of integers
mylist=[23 , 58 , -12 , 90 , -45 , 81 , 49 , -36] 
print("First list : ", mylist)
newlist=[x for x in mylist if x > 0]
print("New list : " ,newlist)
# Out:
# First list :  [23, 58, -12, 90, -45, 81, 49, -36]
# New list :  [23, 58, 90, 81, 49]

# %%
#3b Square of N numbers
mylist=[2 ,5 , 3 , 8]
print("First list : " ,mylist)
newlist=[number ** 2 for number in mylist]
print("New list : " ,newlist)
# Out:
# First list :  [2, 5, 3, 8]
# New list :  [4, 25, 9, 64]

# %%
#3c Form a list of vowels selected from a given word
word=input("Enter a word : ")
vowels=["a" , "e" , "i" , "o" , "u"]
list=[]
for x in word:
  if(x in vowels and x not in list):
    list.append(x)
print("Vowels in the given word : " , list)
# Out:
# Enter a word : apple
# Vowels in the given word :  ['a', 'e']

# %%
#4 Count the occurrences of each word in a line of text
def word_count(str):
    counts = dict()
    words = str.split()
    for word in words:
        if word in counts:
            counts[word] += 1
        else:
            counts[word] = 1
    return counts

print( word_count('Pyhton is a powerful programming language and is very easy.'))
# Out:
# {'Pyhton': 1, 'is': 2, 'a': 1, 'powerful': 1, 'programming': 1, 'language': 1, 'and': 1, 'very': 1, 'easy.': 1}

# %%
#6 Store a list of first names.Count the occurrences of 'a' within the list
name =input("Enter the first names : ")
list = []
count = 0
for x in name:
 list.append(x)
 if(x in name and x == 'a'):
   count = count + 1
print(count)
# Out:
# Enter the first names : dona,arya,deepa
# 4

# %%
#7 Enter 2 list of integers.
#a) check whether lists are of same length
list1 = [1, 2, 4, 3, 8] 
list2 = [1, 2, 4, 3, 5] 
print ("The first list is : " + str(list1)) 
print ("The second list is : " + str(list2)) 
l1 = len(list1)
l2 = len(list2)
print("Length of list1 : " , l1 , "and Length of list2 : " , l2)
if l1 == l2: 
    print ("The lists are of same length") 
else : 
    print ("The lists are of different length")
# Out:
# The first list is : [1, 2, 4, 3, 8]
# The second list is : [1, 2, 4, 3, 5]
# Length of list1 :  5 and Length of list2 :  5
# The lists are of same length

# %%
#7b check whether lists sums to same value
list1 = [1, 2, 4, 3, 8] 
list2 = [1, 2, 4, 3, 5] 
print ("The first list is : " + str(list1)) 
print ("The second list is : " + str(list2)) 
sum1 = 0
sum2 = 0
for x in range(0, len(list1)):
    sum1 = sum1 + list1[x]
print("Sum of all elements in given list1 : ", sum1)
for x in range(0, len(list2)):
    sum2 = sum2 + list2[x]
print("Sum of all elements in given list2 : ", sum2)    
if( sum1 == sum2):
  print("Lists sums to same value")
else:
  print("Lists sums to different value")
# Out:
# The first list is : [1, 2, 4, 3, 8]
# The second list is : [1, 2, 4, 3, 5]
# Sum of all elements in given list1 :  18
# Sum of all elements in given list2 :  15
# Lists sums to different value

# %%
#7c check whether any value occur in both
list1 = [1, 2, 4, 3, 8] 
list2 = [1, 2, 4, 3, 5] 
print ("The first list is : " + str(list1)) 
print ("The second list is : " + str(list2)) 
print("The values occur in both lists : ")
for x in list1:
  if(x in list1 and x in list2):
    print(x)
# Out:
# The first list is : [1, 2, 4, 3, 8]
# The second list is : [1, 2, 4, 3, 5]
# The values occur in both lists :
# 1
# 2
# 4
# 3

# %%
#8 Get a string from an i/p string where all occurrences of 1st character replaced with '$',except 1st character
def change_char(str1):
  char = str1[0]
  str1 = str1.replace(char, '$')
  str1 = char + str1[1:]
  return str1
print(change_char('onion'))
# Out:
# oni$n

# %%
#9 Create a string from given string where first and last characters exchanged
a=input("Enter a string : ")
print("New string : ")
print(a[-1:] + a[1:-1] + a[0])
# Out:
# Enter a string : python
# New string :
# nythop

# %%
#10 Accept the radius from user and find area of circle
r=float(input("Enter radius of circle : "))
pi=3.14
area= pi * r * r
print("Area = " ,area)
# Out:
# Enter radius of circle :
# 2
# Area =  12.56

# %%
#11 Find biggest of three numbers entered
a = float(input("Enter first number : "))
b = float(input("Enter second number : "))
c = float(input("Enter third number : "))
 
if (a > b) and (a > c):
   largest = a
elif (b > a) and (b > c):
   largest = b
else:
   largest = c
 
print("The largest number is",largest)
# Out:
# Enter first number : 49.5
# Enter second number : 21
# Enter third number : 30
# The largest number is 49.5

# %%
#12 Accept a file name from user and print extension of that
filename = input("Enter the Filename : ")
f_extns = filename.split(".")
print ("The extension of the file is : " + repr(f_extns[-1]))
# Out:
# Enter the Filename : sort.html
# The extension of the file is : 'html'

# %%
#13 Create a list of colors from comma-separated color name entered by user.Display 1st & last color
word = input("Enter the colors : ")
color_list = word.split(",")
print("The color list is : " , color_list)
print("The first and last colors are : ")
print( "%s %s"%(color_list[0],color_list[-1]))
# Out:
# Enter the colors : Blue,Green,Yellow,Red
# The color list is :  ['Blue', 'Green', 'Yellow', 'Red']
# The first and last colors are :
# Blue Red

# %%
#14 Accept an integer n and compute n+nn+nnn
a = int(input("Enter an integer : "))
n1 = int( "%s" % a )
n2 = int( "%s%s" % (a,a) )
n3 = int( "%s%s%s" % (a,a,a) )
print(n1+n2+n3)
# Out:
# Enter an integer : 5
# 615

# %%
#15 Print out all colors from color_list1 not contained in color_list2
color_list1 = set(["Red" , "Blue" , "White"])
color_list2 = set(["White" , "Black"])
print(color_list1.difference(color_list2))
# Out:
# {'Blue', 'Red'}

# %%
#16 Create a single string separated with space from two strings by swapping the character at position 1
def chars_mix_up(a, b):
  str1 = a[0] + b[1] + a[2:]
  str2 = b[0] + a[1] + b[2:]

  return str1 + ' ' + str2
print(chars_mix_up('abc', 'xyz'))
# Out:
# ayc xbz

# %%
#17 Sort dictionary in ascending and descending order
y={'della':50,'anna':27,'vidya':49,'keerthi':89}
print("Original dictionary : " , y)
l=list(y.items())
l.sort()
print("Ascending order : " , l)
l=list(y.items())
l.sort(reverse=True)
print("Descending order : " , l)
# Out:
# Original dictionary :  {'della': 50, 'anna': 27, 'vidya': 49, 'keerthi': 89}
# Ascending order :  [('anna', 27), ('della', 50), ('keerthi', 89), ('vidya', 49)]
# Descending order :  [('vidya', 49), ('keerthi', 89), ('della', 50), ('anna', 27)]

# %%
#18 Merge two dictionaries
dict1 = {"a":100 ,"b":200}
dict2 = {"x":300 ,"y":400}
newdict = dict1.copy()
newdict.update(dict2)
print("Merged dictionary : " , newdict)
# Out:
# Merged dictionary :  {'a': 100, 'b': 200, 'x': 300, 'y': 400}

# %%
#19 Find gcd of two numbers
a = int(input("Enter 1st number: "))
b = int(input("Enter 2nd number: "))
i = 1
while(i <= a and i <= b):
  if(a % i == 0 and b % i == 0):
    gcd = i
  i = i + 1
print("GCD is", gcd)
# Out:
# Enter 1st number: 60
# Enter 2nd number: 48
# GCD is 12

# %%
#20 From a list of integers ,create a new list removing even numbers
list = [11, 22, 33, 44, 55]
print("Original list : " , list)
for i  in list:
	if(i%2 == 0):
	    list.remove(i)
print("List after removing EVEN numbers : " , list)
# Out:
# Original list :  [11, 22, 33, 44, 55]
# List after removing EVEN numbers :  [11, 33, 55]
